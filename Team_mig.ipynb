# %%
import pandas as pd

# %%
df = pd.read_csv('DATA/시도_성별_경제활동인구_총괄.csv', encoding='utf-8')
df
# Out:
#     행정구역(시도)  성별      2013.1/2   2013.1/2.1 2013.1/2.2 2013.1/2.3  \
# 0   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)   취업자 (천명)   실업자 (천명)
# 1          계   계         42198        26149      25322        827
# 2          계  남자         20670        15252      14748        504
# 3          계  여자         21528        10897      10575        323
# 4      서울특별시   계          8587         5343       5117        226
# 5      서울특별시  남자          4131         3000       2878        122
# 6      서울특별시  여자          4456         2343       2239        104
# 7      부산광역시   계          2974         1753       1683         70
# 8      부산광역시  남자          1432         1011        966         45
# 9      부산광역시  여자          1542          742        717         26
# 10     대구광역시   계          2077         1243       1204         39
# 11     대구광역시  남자          1005          707        680         27
# 12     대구광역시  여자          1072          536        525         12
# ...
